# %%
import torch
from torch import Tensor
from torch import nn 
from torch.autograd import Variable
import torch.nn.functional as F
import numpy as np
from utility import *

# %%
import dlc_bci

train_input_100 , train_target_100 = dlc_bci.load(root = './data_bci_100Hz', download = False)
test_input_100 , test_target_100 = dlc_bci.load(root = './data_bci_100Hz', download = False, train = False)

train_input_1000 , train_target_1000 = dlc_bci.load(root = './data_bci_1000Hz', download = False, one_khz = True)
test_input_1000 , test_target_1000 = dlc_bci.load(root = './data_bci_1000Hz', download = False, train = False, one_khz = True)

print("Train input 100 Hz: {:d}x{:d}x{:d}".format(*(s for s in train_input_100.size())))
print("Train target 100 Hz: {:d}".format(*(s for s in train_target_100.size())))
print("Test input 100 Hz: {:d}x{:d}x{:d}".format(*(s for s in test_input_100.size())))
print("Test target 100 Hz: {:d}".format(*(s for s in test_target_100.size())))
print("")
print("Train input 1000 Hz: {:d}x{:d}x{:d}".format(*(s for s in train_input_1000.size())))
print("Train target 1000 Hz: {:d}".format(*(s for s in train_target_1000.size())))
print("Test input 1000 Hz: {:d}x{:d}x{:d}".format(*(s for s in test_input_1000.size())))
print("Test target 1000 Hz: {:d}".format(*(s for s in test_target_1000.size())))

Ntrain = train_input_100.size(0)
Ntest = test_input_100.size(0)
Nchannels = train_input_100.size(1)
Nsamples_100 = train_input_100.size(-1)
Nsamples_1000 = train_input_1000.size(-1)
# Out:
# Train input 100 Hz: 316x28x50
# Train target 100 Hz: 316
# Test input 100 Hz: 100x28x50
# Test target 100 Hz: 100
#
# Train input 1000 Hz: 316x28x500
# Train target 1000 Hz: 316
# Test input 1000 Hz: 100x28x500
# Test target 1000 Hz: 100

# %% [markdown]
# # Network definition

# %%
class conv2DNet(nn.Module):
    
    def __init__(self, Nchannels, Nsamples, output_units):
        """Initializes neural network with 3 convolutional layers and 1 fully-connected layer.
        
        Args:
            - Nchannels (int): number of EEG channels
            - Nsamples (int): number of time points in each EEG signal
            - output_units (int): number of output units, e.g. 1 for training with loss torch.nn.BCELoss or 2 with 
            loss torch.nn.CrossEntropyLoss            
            
            """
        super(conv2DNet, self).__init__()
        
        self.fc_inputs = 4*1*42
        
        # Layer 1
        channelsConv1a = 4
        channelsConv1b = 4
        
        self.conv1a = nn.Conv2d(1, channelsConv1a, (1, 5), dilation = 2)  # does not change size if combined with above padding
        self.batchnorm1a = nn.BatchNorm2d(channelsConv1a, False)
        self.conv1b = nn.Conv2d(channelsConv1a, channelsConv1b, (28, 1))  # does not change size if combined with above padding
        self.batchnorm1b = nn.BatchNorm2d(channelsConv1b, False)
        #self.pooling1 = nn.MaxPool2d((2, 2), stride = 2) 

        '''# Layer 2
        channelsConv2a = 32
        channelsConv2b = 64
        
        self.conv2a = nn.Conv2d(channelsConv1b, channelsConv2a, (28, 1))  # does not change size if combined with above padding
        self.batchnorm2a = nn.BatchNorm2d(channelsConv2a, False)
        self.conv2b = nn.Conv2d(channelsConv2a, channelsConv2b, (3, 3))  # does not change size if combined with above padding
        self.batchnorm2b = nn.BatchNorm2d(channelsConv2b)
        self.pooling2 = nn.MaxPool2d((2, 2), stride = 2)  

        # Layer 3
        channelsConv3a = 128 
        channelsConv3b = 256
        
        self.conv3a = nn.Conv2d(channelsConv2b, channelsConv3a, (3, 3), padding=1)  # does not change size if combined with above padding
        self.batchnorm3a = nn.BatchNorm2d(channelsConv3a)
        self.conv3b = nn.Conv2d(channelsConv3a, channelsConv3b, (3, 3), padding=1)  # does not change size if combined with above padding
        self.batchnorm3b = nn.BatchNorm2d(channelsConv3b)
        self.pooling3 = nn.MaxPool2d((2, 2), stride = 2) '''
        
        # FC Layer
        self.fc1 = nn.Linear(self.fc_inputs, 64)
        self.fc2 = nn.Linear(64, output_units)

        
    def forward(self, x):
        """Applies forward pass consisting of 3 convolutional layers followed by a fully-connected linear layer.
        
        Args:
            - x (torch.autograd.Variable): the input batch. It has dimension batch_size x Nchannel x Nsamples x 1,
            where Nchannel is the number of EEG channels and Nsamples the number of time points.
        
        Returns:
            - (torch.autograd.Variable) of size either batch_size x output_units   
        
        """
    
        # Layer 1
        x = self.conv1a(x)              # bsize x l1_channels x 1 x Nsamples
        x = self.batchnorm1a(x)
        x = self.conv1b(x)                     # bsize x l1_channels x 1 x Nsamples
        x = self.batchnorm1b(x)
        #x = self.pooling1(x)
        #x = F.dropout2d(x, 0.5)

        # Layer 2
        #x = self.conv2a(x)             # bsize x l1_channels x 1 x Nsamples
        #x = self.batchnorm2a(x)
        #x = F.relu(self.conv2b(x))              # bsize x l1_channels x 1 x Nsamples
        #x = self.batchnorm2b(x)
        #x = self.pooling2(x)
        #x = F.dropout2d(x, 0.5)

        '''# Layer 3
        x = F.relu(self.conv3a(x))              # bsize x l1_channels x 1 x Nsamples
        x = self.batchnorm3a(x)
        x = F.relu(self.conv3b(x))              # bsize x l1_channels x 1 x Nsamples
        x = self.batchnorm3b(x)
        x = self.pooling3(x)
        x = F.dropout2d(x, 0.5)'''
        
        #print(x.shape)
        
        # Fully-connected Layer
        x = x.view(-1, self.fc_inputs)  # bsize x (l3_channels*floor(l1_channels/4)*floor(Nsamples/16))
        
        x = F.relu(self.fc1(x))
        x = F.dropout(x, 0.6)
        x = F.sigmoid(self.fc2(x)) 
        
        if self.fc2.out_features == 1:
            x = x.view(-1)                     # bsize (1D if 1 output unit)
        
        #print(x.shape)
        return x

# %%
def compute_nb_errors(model, data_input, data_target, batch_size):
    nb_errors = 0
    Ndata = data_input.size(0)
    model.eval()
    
    for b_start in range(0, data_input.size(0), batch_size):
        bsize_eff = batch_size - max(0, b_start+batch_size-Ndata)  # boundary case
        batch_output = model.forward(data_input.narrow(0, b_start, bsize_eff))  # is Variable if data_input is Variable
        if len(list(batch_output.size()))>1 and batch_output.size(1) > 1:
            # as many ouputs as there are classes => select maximum output
            nb_err_batch = (batch_output.max(1)[1] != data_target.narrow(0, b_start, bsize_eff)).long().sum()
            # overflow problem if conversion to Long Int not performed, treated as short 1-byte int otherwise!!
        else:
            # output is a scalar in [0, 1]
            nb_err_batch = batch_output.round().sub(data_target.narrow(0, b_start, bsize_eff)).sign().abs().sum()
        
        nb_errors += nb_err_batch
    if isinstance(nb_errors, Variable):
        nb_errors = nb_errors.data[0]
    return nb_errors

# %% [markdown]
# # Preprocessing and Data Augmentation

# %%
import numpy as np

preprocessed_input_train, preprocessed_input_validation, preprocessed_input_train_target, preprocessed_input_validation_target = preprocessing_train_100(train_input_1000, train_target_1000, False, False)
preprocessed_input_test = preprocessing_test_100(test_input_100, False)

#Remove Noise
#preprocessed_input_train = denoisedSignals(preprocessed_input_train)
#preprocessed_input_validation = denoisedSignals(preprocessed_input_validation)
#preprocessed_input_test = denoisedSignals(preprocessed_input_test)
#add random noise
#preprocessed_input_train = whiteNoise(preprocessed_input_train)
#preprocessed_input_validation = whiteNoise(preprocessed_input_validation)
#preprocessed_input_test = whiteNoise(preprocessed_input_test)

print('train', preprocessed_input_train.shape)
print('test', preprocessed_input_test.shape)
print('validation', preprocessed_input_validation.shape)

labels_train = torch.from_numpy(preprocessed_input_train_target)
labels_test = test_target_100
labels_validation = torch.from_numpy(preprocessed_input_validation_target)

preprocessed_input_train = torch.from_numpy(preprocessed_input_train).float()
preprocessed_input_test = torch.from_numpy(preprocessed_input_test).float()
preprocessed_input_validation = torch.from_numpy(preprocessed_input_validation).float()

preprocessed_input_train_target = torch.from_numpy(preprocessed_input_train_target)
preprocessed_input_validation_target = torch.from_numpy(preprocessed_input_validation_target)

Ntrain = len(preprocessed_input_train[:,0,0])
Ntest = len(preprocessed_input_test[:,0,0])
Nvalidation = len(preprocessed_input_validation[:,0,0])

print('Ntrain', Ntrain)
print('Ntest', Ntest)
print('Nvalidation', Nvalidation)

train_input = Variable(preprocessed_input_train.view(Ntrain, 1, Nchannels, Nsamples_100))
validation_input = Variable(preprocessed_input_validation.view(Nvalidation, 1, Nchannels, Nsamples_100), volatile=True )
test_input = Variable(preprocessed_input_test.view(Ntest, 1, Nchannels, Nsamples_100), volatile=True )
# Out:
# train (3000, 28, 50)
# test (100, 28, 50)
# validation (160, 28, 50)
# Ntrain 3000
# Ntest 100
# Nvalidation 160

# %% [markdown]
# # Network training and testing
# Non-linearity: elu
#
#
# |criterion | optimizer | lr  | momentum | batch size | Nepochs | Train acc. | Test acc.|
# |----------|-----------|-----|----------|------------|---------|------------|----------|
# | BCE  | Adam  |1e-1 | def. | 15 | 150 | 86.4 | 61.4 |
# | BCE  | Adam  |1e-1 | def. | 20 | 150 | 99.8 | 79.5 |
# | BCE  | SGD   | 1e-2 | 0.85 | 20 | 150 | 98.9  | 61.5 |
# | CE   | Adam  | 1e-2 | def. | 20 | 150 | 98.4  |  70.5 |
# | CE   | SGD   | 1e-2 | 0.85 | 20 | 150 | 99.1 | 75.1 |
#
#
# Non-linearity: ReLU

# %%
import torch.optim as optim
import math

# Train network 
criterion = nn.BCELoss()
#criterion = nn.CrossEntropyLoss()
#criterion = nn.PoissonNLLLoss()
#criterion = nn.BCEWithLogitsLoss()
#criterion = nn.SmoothL1Loss() #interesting ... but does not converge
#criterion = nn.MSELoss() #0.83 but unstable

if isinstance(criterion, nn.CrossEntropyLoss):
    train_target = Variable(preprocessed_input_train_target)  # keep long tensors
    validation_target = Variable(preprocessed_input_validation_target, volatile=True) # convert to float
    test_target = Variable(test_target_100, volatile=True )
    Noutputs = 2
    
elif isinstance(criterion, nn.NLLLoss):
    train_target = Variable(preprocessed_input_train_target)  # keep long tensors
    validation_target = Variable(preprocessed_input_validation_target, volatile=True) # convert to float
    test_target = Variable(test_target_100, volatile=True )
    Noutputs = 2
    
else:
    train_target = Variable(preprocessed_input_train_target.float()) # convert to float
    validation_target = Variable(preprocessed_input_validation_target.float(), volatile=True ) # convert to float
    test_target = Variable(test_target_100.float(), volatile=True )
    Noutputs = 1
        
model = conv2DNet(Nchannels, Nsamples_100, Noutputs)

optimizer = optim.SGD(model.parameters(), lr=1e-3, momentum=0.4)
#optimizer = optim.Adam(model.parameters())
#optimizer = optim.Adagrad(model.parameters())
#optimizer = optim.Adamax(model.parameters())
#optimizer = optim.ASGD(model.parameters())
#optimizer = optim.RMSprop(model.parameters())
#optimizer = optim.Rprop(model.parameters())

scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=10, verbose=True)

batch_size = 15
Nbatches = int(math.ceil(Ntrain/batch_size))
Nepochs = 100
Nrep = 1

train_errors = torch.Tensor(Nepochs).zero_()
test_errors = torch.Tensor(Nepochs).zero_()
validation_errors = torch.Tensor(Nepochs).zero_()

ep_loss = torch.Tensor(Nepochs).zero_()

for i_rep in range(Nrep):
    for i_ep in range(Nepochs):
        for b_start in range(0, Ntrain, batch_size):
            bsize_eff = batch_size - max(0, b_start+batch_size-Ntrain)  # boundary case
            model.train()
            model.zero_grad()
            output = model(train_input.narrow(0, b_start, bsize_eff))
            batch_loss = criterion(output, train_target.narrow(0, b_start, bsize_eff))            
            ep_loss[i_ep] += batch_loss.data[0]
            batch_loss.backward()
            optimizer.step()
        
        scheduler.step(ep_loss[i_ep])
        
        nb_train_errs = compute_nb_errors(model, train_input, train_target, batch_size)
        nb_validation_errs = compute_nb_errors(model, validation_input, validation_target, batch_size)
        nb_test_errs = compute_nb_errors(model, test_input, test_target, batch_size)
        
        print("Epoch Number : ", i_ep)
        print("\t Training accuracy: ", (100*(Ntrain-nb_train_errs)/Ntrain))
        print("\t Validation accuracy ",(100*(Nvalidation-nb_validation_errs)/Nvalidation)) 
        print("\t Test accuracy ",(100*(Ntest-nb_test_errs)/Ntest))
        
        print("\t Epoch Loss ", ep_loss[i_ep])
        
        train_errors[i_ep] = nb_train_errs
        test_errors[i_ep] = nb_test_errs
        validation_errors[i_ep] = nb_validation_errs
# Out:
# Epoch Number :  0
# 	 Training accuracy:  54.233333333333334
# 	 Validation accuracy  50.625
# 	 Test accuracy  50.0
# 	 Epoch Loss  138.55322265625
# Epoch Number :  1
# 	 Training accuracy:  57.233333333333334
# 	 Validation accuracy  49.375
# 	 Test accuracy  51.0
# 	 Epoch Loss  137.4213104248047
# Epoch Number :  2
# 	 Training accuracy:  59.733333333333334
# 	 Validation accuracy  48.75
# 	 Test accuracy  53.0
# 	 Epoch Loss  136.52117919921875
# Epoch Number :  3
# 	 Training accuracy:  62.666666666666664
# 	 Validation accuracy  52.5
# 	 Test accuracy  59.0
# 	 Epoch Loss  135.45021057128906
# Epoch Number :  4
# 	 Training accuracy:  68.0
# 	 Validation accuracy  53.75
# 	 Test accuracy  59.0
# 	 Epoch Loss  133.59841918945312
# Epoch Number :  5
# 	 Training accuracy:  75.03333333333333
# 	 Validation accuracy  55.625
# 	 Test accuracy  73.0
# 	 Epoch Loss  129.74337768554688
# Epoch Number :  6
# 	 Training accuracy:  79.6
# 	 Validation accuracy  65.625
# 	 Test accuracy  78.0
# 	 Epoch Loss  124.10914611816406
# Epoch Number :  7
# 	 Training accuracy:  80.16666666666667
# 	 Validation accuracy  68.125
# 	 Test accuracy  77.0
# 	 Epoch Loss  117.9483871459961
# Epoch Number :  8
# 	 Training accuracy:  81.33333333333333
# 	 Validation accuracy  73.125
# 	 Test accuracy  79.0
# 	 Epoch Loss  112.1446304321289
# Epoch Number :  9
# 	 Training accuracy:  81.56666666666666
# 	 Validation accuracy  77.5
# 	 Test accuracy  80.0
# 	 Epoch Loss  106.69023895263672
# Epoch Number :  10
# 	 Training accuracy:  82.4
# 	 Validation accuracy  78.75
# 	 Test accuracy  81.0
# 	 Epoch Loss  101.8821792602539
# Epoch Number :  11
# 	 Training accuracy:  83.53333333333333
# 	 Validation accuracy  78.75
# 	 Test accuracy  80.0
# 	 Epoch Loss  97.14791870117188
# Epoch Number :  12
# 	 Training accuracy:  84.43333333333334
# 	 Validation accuracy  79.375
# 	 Test accuracy  79.0
# 	 Epoch Loss  92.20569610595703
# Epoch Number :  13
# 	 Training accuracy:  85.3
# 	 Validation accuracy  80.625
# 	 Test accuracy  80.0
# 	 Epoch Loss  87.61634826660156
# Epoch Number :  14
# 	 Training accuracy:  86.1
# 	 Validation accuracy  80.625
# 	 Test accuracy  80.0
# 	 Epoch Loss  83.34521484375
# Epoch Number :  15
# 	 Training accuracy:  86.5
# 	 Validation accuracy  80.625
# 	 Test accuracy  79.0
# 	 Epoch Loss  79.43194580078125
# Epoch Number :  16
# 	 Training accuracy:  86.93333333333334
# 	 Validation accuracy  81.25
# 	 Test accuracy  79.0
# 	 Epoch Loss  75.94050598144531
# Epoch Number :  17
# 	 Training accuracy:  87.16666666666667
# 	 Validation accuracy  81.25
# 	 Test accuracy  80.0
# 	 Epoch Loss  72.75739288330078
# Epoch Number :  18
# 	 Training accuracy:  87.33333333333333
# 	 Validation accuracy  81.875
# 	 Test accuracy  81.0
# 	 Epoch Loss  70.00952911376953
# Epoch Number :  19
# 	 Training accuracy:  87.86666666666666
# 	 Validation accuracy  82.5
# 	 Test accuracy  82.0
# 	 Epoch Loss  67.39913177490234
# Epoch Number :  20
# 	 Training accuracy:  88.03333333333333
# 	 Validation accuracy  82.5
# 	 Test accuracy  84.0
# 	 Epoch Loss  65.11502075195312
# Epoch Number :  21
# 	 Training accuracy:  88.76666666666667
# 	 Validation accuracy  82.5
# 	 Test accuracy  84.0
# 	 Epoch Loss  63.12474822998047
# Epoch Number :  22
# 	 Training accuracy:  89.0
# 	 Validation accuracy  82.5
# 	 Test accuracy  84.0
# 	 Epoch Loss  61.13149642944336
# Epoch Number :  23
# 	 Training accuracy:  89.1
# 	 Validation accuracy  83.125
# 	 Test accuracy  85.0
# 	 Epoch Loss  59.3425407409668
# Epoch Number :  24
# 	 Training accuracy:  89.33333333333333
# 	 Validation accuracy  83.125
# 	 Test accuracy  86.0
# 	 Epoch Loss  57.62928771972656
# Epoch Number :  25
# 	 Training accuracy:  89.56666666666666
# 	 Validation accuracy  83.75
# 	 Test accuracy  86.0
# 	 Epoch Loss  56.124061584472656
# Epoch Number :  26
# 	 Training accuracy:  89.73333333333333
# 	 Validation accuracy  83.75
# 	 Test accuracy  86.0
# 	 Epoch Loss  54.69505310058594
# Epoch Number :  27
# 	 Training accuracy:  89.5
# 	 Validation accuracy  84.375
# 	 Test accuracy  86.0
# 	 Epoch Loss  53.31864929199219
# Epoch Number :  28
# 	 Training accuracy:  89.33333333333333
# 	 Validation accuracy  84.375
# 	 Test accuracy  86.0
# 	 Epoch Loss  52.07136917114258
# Epoch Number :  29
# 	 Training accuracy:  89.46666666666667
# 	 Validation accuracy  85.0
# 	 Test accuracy  86.0
# 	 Epoch Loss  50.79553985595703
# Epoch Number :  30
# 	 Training accuracy:  89.43333333333334
# 	 Validation accuracy  84.375
# 	 Test accuracy  86.0
# 	 Epoch Loss  49.6514778137207
# Epoch Number :  31
# 	 Training accuracy:  89.26666666666667
# 	 Validation accuracy  83.75
# 	 Test accuracy  86.0
# 	 Epoch Loss  48.53468322753906
# Epoch Number :  32
# 	 Training accuracy:  89.1
# 	 Validation accuracy  83.75
# 	 Test accuracy  86.0
# 	 Epoch Loss  47.46162414550781
# Epoch Number :  33
# 	 Training accuracy:  89.5
# 	 Validation accuracy  83.75
# 	 Test accuracy  86.0
# 	 Epoch Loss  46.399227142333984
# Epoch Number :  34
# 	 Training accuracy:  89.5
# 	 Validation accuracy  83.125
# 	 Test accuracy  86.0
# 	 Epoch Loss  45.3510627746582
# Epoch Number :  35
# 	 Training accuracy:  90.33333333333333
# 	 Validation accuracy  83.125
# 	 Test accuracy  86.0
# 	 Epoch Loss  44.283546447753906
# Epoch Number :  36
# 	 Training accuracy:  89.83333333333333
# 	 Validation accuracy  81.25
# 	 Test accuracy  86.0
# 	 Epoch Loss  43.213600158691406
# Epoch Number :  37
# 	 Training accuracy:  90.03333333333333
# 	 Validation accuracy  81.25
# 	 Test accuracy  86.0
# 	 Epoch Loss  42.171451568603516
# Epoch Number :  38
# 	 Training accuracy:  90.26666666666667
# 	 Validation accuracy  81.25
# 	 Test accuracy  85.0
# 	 Epoch Loss  41.17770004272461
# Epoch Number :  39
# 	 Training accuracy:  90.5
# 	 Validation accuracy  81.25
# 	 Test accuracy  85.0
# 	 Epoch Loss  40.23846435546875
# Epoch Number :  40
# 	 Training accuracy:  91.13333333333334
# 	 Validation accuracy  81.25
# 	 Test accuracy  85.0
# 	 Epoch Loss  39.37654113769531
# Epoch Number :  41
# 	 Training accuracy:  91.36666666666666
# 	 Validation accuracy  81.25
# 	 Test accuracy  85.0
# 	 Epoch Loss  38.417999267578125
# Epoch Number :  42
# 	 Training accuracy:  91.4
# 	 Validation accuracy  81.25
# 	 Test accuracy  85.0
# 	 Epoch Loss  37.48683166503906
# Epoch Number :  43
# 	 Training accuracy:  91.46666666666667
# 	 Validation accuracy  81.25
# 	 Test accuracy  84.0
# 	 Epoch Loss  36.46783447265625
# Epoch Number :  44
# 	 Training accuracy:  91.63333333333334
# 	 Validation accuracy  81.25
# 	 Test accuracy  84.0
# 	 Epoch Loss  35.547420501708984
# Epoch Number :  45
# 	 Training accuracy:  92.16666666666667
# 	 Validation accuracy  81.25
# 	 Test accuracy  84.0
# 	 Epoch Loss  34.63867950439453
# Epoch Number :  46
# 	 Training accuracy:  92.13333333333334
# 	 Validation accuracy  81.25
# 	 Test accuracy  84.0
# 	 Epoch Loss  33.74128723144531
# Epoch Number :  47
# 	 Training accuracy:  91.4
# 	 Validation accuracy  80.0
# 	 Test accuracy  84.0
# 	 Epoch Loss  32.93999481201172
# Epoch Number :  48
# 	 Training accuracy:  92.36666666666666
# 	 Validation accuracy  81.25
# 	 Test accuracy  84.0
# 	 Epoch Loss  32.100059509277344
# Epoch Number :  49
# 	 Training accuracy:  92.46666666666667
# 	 Validation accuracy  81.25
# 	 Test accuracy  83.0
# 	 Epoch Loss  31.251121520996094
# Epoch Number :  50
# 	 Training accuracy:  92.63333333333334
# 	 Validation accuracy  81.25
# 	 Test accuracy  83.0
# 	 Epoch Loss  30.497478485107422
# Epoch Number :  51
# 	 Training accuracy:  93.06666666666666
# 	 Validation accuracy  80.625
# 	 Test accuracy  83.0
# 	 Epoch Loss  29.674053192138672
# Epoch Number :  52
# 	 Training accuracy:  93.43333333333334
# 	 Validation accuracy  80.625
# 	 Test accuracy  83.0
# 	 Epoch Loss  28.87599754333496
# Epoch Number :  53
# 	 Training accuracy:  93.33333333333333
# 	 Validation accuracy  80.625
# 	 Test accuracy  83.0
# 	 Epoch Loss  28.12644386291504
# Epoch Number :  54
# 	 Training accuracy:  93.56666666666666
# 	 Validation accuracy  79.375
# 	 Test accuracy  83.0
# 	 Epoch Loss  27.336078643798828
# Epoch Number :  55
# 	 Training accuracy:  94.46666666666667
# 	 Validation accuracy  80.0
# 	 Test accuracy  83.0
# 	 Epoch Loss  26.56511878967285
# Epoch Number :  56
# 	 Training accuracy:  94.53333333333333
# 	 Validation accuracy  80.0
# 	 Test accuracy  82.0
# 	 Epoch Loss  25.86537742614746
# Epoch Number :  57
# 	 Training accuracy:  94.93333333333334
# 	 Validation accuracy  80.0
# 	 Test accuracy  82.0
# 	 Epoch Loss  25.068578720092773
# Epoch Number :  58
# 	 Training accuracy:  94.36666666666666
# 	 Validation accuracy  78.75
# 	 Test accuracy  80.0
# 	 Epoch Loss  24.339916229248047
# Epoch Number :  59
# 	 Training accuracy:  95.3
# 	 Validation accuracy  79.375
# 	 Test accuracy  83.0
# 	 Epoch Loss  23.750043869018555
# Epoch Number :  60
# 	 Training accuracy:  95.63333333333334
# 	 Validation accuracy  79.375
# 	 Test accuracy  83.0
# 	 Epoch Loss  23.07353401184082
# Epoch Number :  61
# 	 Training accuracy:  95.2
# 	 Validation accuracy  78.125
# 	 Test accuracy  80.0
# 	 Epoch Loss  22.428335189819336
# Epoch Number :  62
# 	 Training accuracy:  96.13333333333334
# 	 Validation accuracy  79.375
# 	 Test accuracy  80.0
# 	 Epoch Loss  21.783220291137695
# Epoch Number :  63
# 	 Training accuracy:  96.4
# 	 Validation accuracy  79.375
# 	 Test accuracy  80.0
# 	 Epoch Loss  21.0793514251709
# Epoch Number :  64
# 	 Training accuracy:  96.2
# 	 Validation accuracy  77.5
# 	 Test accuracy  80.0
# 	 Epoch Loss  20.451087951660156
# Epoch Number :  65
# 	 Training accuracy:  96.5
# 	 Validation accuracy  78.125
# 	 Test accuracy  79.0
# 	 Epoch Loss  19.88233184814453
# Epoch Number :  66
# 	 Training accuracy:  96.66666666666667
# 	 Validation accuracy  78.125
# 	 Test accuracy  78.0
# 	 Epoch Loss  19.272117614746094
# Epoch Number :  67
# 	 Training accuracy:  96.5
# 	 Validation accuracy  77.5
# 	 Test accuracy  80.0
# 	 Epoch Loss  18.663494110107422
# Epoch Number :  68
# 	 Training accuracy:  96.7
# 	 Validation accuracy  78.125
# 	 Test accuracy  79.0
# 	 Epoch Loss  18.07891845703125
# Epoch Number :  69
# 	 Training accuracy:  97.06666666666666
# 	 Validation accuracy  78.75
# 	 Test accuracy  79.0
# 	 Epoch Loss  17.505868911743164
# Epoch Number :  70
# 	 Training accuracy:  96.93333333333334
# 	 Validation accuracy  78.125
# 	 Test accuracy  80.0
# 	 Epoch Loss  16.933809280395508
# Epoch Number :  71
# 	 Training accuracy:  97.1
# 	 Validation accuracy  78.125
# 	 Test accuracy  79.0
# 	 Epoch Loss  16.399276733398438
# Epoch Number :  72
# 	 Training accuracy:  97.1
# 	 Validation accuracy  77.5
# 	 Test accuracy  79.0
# 	 Epoch Loss  15.89406681060791
# Epoch Number :  73
# 	 Training accuracy:  97.2
# 	 Validation accuracy  77.5
# 	 Test accuracy  80.0
# 	 Epoch Loss  15.38427448272705
# Epoch Number :  74
# 	 Training accuracy:  97.3
# 	 Validation accuracy  77.5
# 	 Test accuracy  80.0
# 	 Epoch Loss  14.93416690826416
# Epoch Number :  75
# 	 Training accuracy:  97.4
# 	 Validation accuracy  77.5
# 	 Test accuracy  80.0
# 	 Epoch Loss  14.461195945739746
# Epoch Number :  76
# 	 Training accuracy:  97.43333333333334
# 	 Validation accuracy  76.875
# 	 Test accuracy  80.0
# 	 Epoch Loss  13.99047565460205
# Epoch Number :  77
# 	 Training accuracy:  97.53333333333333
# 	 Validation accuracy  76.875
# 	 Test accuracy  80.0
# 	 Epoch Loss  13.565649032592773
# Epoch Number :  78
# 	 Training accuracy:  97.56666666666666
# 	 Validation accuracy  76.875
# 	 Test accuracy  80.0
# 	 Epoch Loss  13.16901969909668
# Epoch Number :  79
# 	 Training accuracy:  97.73333333333333
# 	 Validation accuracy  76.875
# 	 Test accuracy  79.0
# 	 Epoch Loss  12.7227144241333
# Epoch Number :  80
# 	 Training accuracy:  97.73333333333333
# 	 Validation accuracy  76.875
# 	 Test accuracy  80.0
# 	 Epoch Loss  12.312270164489746
# Epoch Number :  81
# 	 Training accuracy:  97.93333333333334
# 	 Validation accuracy  76.875
# 	 Test accuracy  80.0
# 	 Epoch Loss  11.929219245910645
# Epoch Number :  82
# 	 Training accuracy:  98.0
# 	 Validation accuracy  76.875
# 	 Test accuracy  80.0
# 	 Epoch Loss  11.537641525268555
# Epoch Number :  83
# 	 Training accuracy:  98.0
# 	 Validation accuracy  75.625
# 	 Test accuracy  80.0
# 	 Epoch Loss  11.167243957519531
# Epoch Number :  84
# 	 Training accuracy:  98.06666666666666
# 	 Validation accuracy  75.625
# 	 Test accuracy  80.0
# 	 Epoch Loss  10.83024787902832
# Epoch Number :  85
# 	 Training accuracy:  98.16666666666667
# 	 Validation accuracy  75.0
# 	 Test accuracy  80.0
# 	 Epoch Loss  10.4902982711792
# Epoch Number :  86
# 	 Training accuracy:  98.26666666666667
# 	 Validation accuracy  75.0
# 	 Test accuracy  80.0
# 	 Epoch Loss  10.150788307189941
# Epoch Number :  87
# 	 Training accuracy:  98.23333333333333
# 	 Validation accuracy  75.0
# 	 Test accuracy  81.0
# 	 Epoch Loss  9.821460723876953
# Epoch Number :  88
# 	 Training accuracy:  98.26666666666667
# 	 Validation accuracy  74.375
# 	 Test accuracy  81.0
# 	 Epoch Loss  9.526490211486816
# Epoch Number :  89
# 	 Training accuracy:  98.3
# 	 Validation accuracy  74.375
# 	 Test accuracy  81.0
# 	 Epoch Loss  9.21723461151123
# Epoch Number :  90
# 	 Training accuracy:  98.26666666666667
# 	 Validation accuracy  74.375
# 	 Test accuracy  81.0
# 	 Epoch Loss  8.935829162597656
# Epoch Number :  91
# 	 Training accuracy:  98.26666666666667
# 	 Validation accuracy  74.375
# 	 Test accuracy  81.0
# 	 Epoch Loss  8.645691871643066
# Epoch Number :  92
# 	 Training accuracy:  98.26666666666667
# 	 Validation accuracy  75.625
# 	 Test accuracy  81.0
# 	 Epoch Loss  8.4325590133667
# Epoch Number :  93
# 	 Training accuracy:  98.33333333333333
# 	 Validation accuracy  75.0
# 	 Test accuracy  81.0
# 	 Epoch Loss  8.140436172485352
# Epoch Number :  94
# 	 Training accuracy:  98.33333333333333
# 	 Validation accuracy  74.375
# 	 Test accuracy  80.0
# 	 Epoch Loss  7.88069486618042
# Epoch Number :  95
# 	 Training accuracy:  98.43333333333334
# 	 Validation accuracy  74.375
# 	 Test accuracy  80.0
# 	 Epoch Loss  7.646377086639404
# Epoch Number :  96
# 	 Training accuracy:  98.46666666666667
# 	 Validation accuracy  75.0
# 	 Test accuracy  80.0
# 	 Epoch Loss  7.414630889892578
# Epoch Number :  97
# 	 Training accuracy:  98.5
# 	 Validation accuracy  75.0
# 	 Test accuracy  80.0
# 	 Epoch Loss  7.184410572052002
# Epoch Number :  98
# 	 Training accuracy:  98.5
# 	 Validation accuracy  75.0
# 	 Test accuracy  80.0
# 	 Epoch Loss  6.968407154083252
# Epoch Number :  99
# 	 Training accuracy:  98.56666666666666
# 	 Validation accuracy  75.0
# 	 Test accuracy  80.0
# 	 Epoch Loss  6.7536797523498535

# %%
plt.plot(np.array(train_errors))
plt.plot(np.array(validation_errors))
plt.plot(np.array(test_errors))
plt.show()

# %%
plt.plot(100*(Ntrain-np.array(train_errors))/Ntrain)
plt.plot(100*(Nvalidation-np.array(validation_errors))/Nvalidation)
plt.plot(100*(Ntest-np.array(test_errors))/Ntest)

plt.show()
